# %% [markdown]
# ##Project Information##
#
# *   **Title**: **Predicting Bank Customer Churn Using Artificial Neural Networks**
# *   **Students : Ankit Sharma(055059)**
#
# ---
# ##Project Overview##
# In today’s competitive banking environment, retaining customers is more cost-effective than acquiring new ones. This project focuses on predicting customer churn — the likelihood of a customer leaving the bank — using an Artificial Neural Network (ANN) model.
#
# The analysis is based on a dataset containing key customer attributes, including demographic information (such as age, gender, and country), financial data (credit score, account balance, estimated salary), and behavioral indicators (tenure, product usage, activity level).
#
# The **primary objective** of this project is **to build a predictive model that can accurately identify customers at risk of churning.**
# The ANN model is designed and trained using TensorFlow/Keras, leveraging its ability to capture non-linear patterns and interactions between features.
#
# By analyzing the churn patterns, this project also provides valuable insights and actionable recommendations that can help banks improve customer retention, tailor personalized engagement strategies, and ultimately reduce revenue loss due to attrition.
#
# ---
# ##Importance of Churn Rate in Banking##
# Customer churn rate is a critical metric in the banking industry as it directly impacts revenue, growth, and brand reputation. Churn refers to the percentage of customers who stop using a bank’s services over a given period. Monitoring and minimizing churn is essential for long-term sustainability. Here's why:
#
# **1. Cost of Acquisition vs. Retention**
# Acquiring new customers is significantly more expensive than retaining existing ones. Reducing churn helps banks maximize the return on investment in customer acquisition.
#
# **2. Revenue Preservation**
# Churned customers often represent lost deposits, loan accounts, credit card usage, and cross-sell opportunities. A high churn rate leads to a decline in revenue streams.
#
# **3. Customer Lifetime Value (CLV)**
# Retaining customers extends their lifetime value — the total net profit a bank can expect from a customer over time. Reducing churn increases CLV and long-term profitability.
#
# **4. Market Reputation and Trust**
# Frequent customer exits can reflect poorly on a bank's service quality. Lower churn rates indicate higher customer satisfaction and trust.
#
# **5. Predictive Strategy and Personalization**
# Understanding churn behavior enables banks to proactively intervene with at-risk customers through personalized offerings, loyalty rewards, or improved service quality.
#
# ---
#
# ##Key Steps Involved in the Project##
# **1. Problem Definition**
# -Identified the need to predict customer churn in a bank to minimize revenue loss and improve customer retention.
#
# -Defined the target variable (churn) for binary classification.
#
# **2. Data Collection & Understanding**
# -Used the Bank Customer Churn Dataset containing demographic, financial, and behavioral data of customers.
#
# -Explored dataset shape, missing values, data types, and class balance.
#
# **3. Data Preprocessing**
# -Handled missing values and irrelevant columns.
#
# -Converted categorical variables using one-hot encoding and label encoding.
#
# -Scaled numerical features using standardization for better ANN performance.
#
# -Split the dataset into training and testing sets.
#
# **4. Model Building: Artificial Neural Network (ANN)**
# -Built a multi-layer ANN using TensorFlow/Keras.
#
# -Used ReLU activation for hidden layers and sigmoid activation for the output.
#
# -Applied dropout layers to prevent overfitting.
#
# -Compiled the model with Adam optimizer and binary cross-entropy loss.
#
# **5. Model Training**
# -Trained the model on the training set for 50 epochs with batch size 32.
#
# -Monitored validation performance using accuracy and loss curves.
#
# **6. Model Evaluation**
# -Evaluated performance on the test set using:
#
# -Accuracy
#
# -Confusion matrix
#
# -Precision, recall, F1-score
#
# -ROC-AUC Score
#
# **7. Interpretation & Insights**
# -Identified key factors leading to churn (e.g., age, activity status, balance).
#
# -Suggested managerial actions based on predictive insights.
#
# **8. Conclusion & Recommendation**
# -Demonstrated the potential of ANN in churn prediction.
#
# -Provided actionable recommendations for customer retention strategies.
#
# ---
# ##Why Use Artificial Neural Networks (ANN) for This Project?##
# Artificial Neural Networks (ANNs) are particularly well-suited for churn prediction in banking due to the following reasons:
#
# **1. Ability to Capture Complex Patterns**
# Bank customer churn is influenced by multiple interacting factors like age, balance, credit score, and activity level. ANN models are powerful at learning non-linear and hidden relationships between these variables, which traditional models (like logistic regression) may not capture well.
#
# **2. High Predictive Accuracy**
# ANNs, when properly trained and tuned, typically achieve higher accuracy compared to basic machine learning algorithms, especially when the dataset is rich and has diverse feature types (numerical, categorical).
#
# **3. Feature Learning**
# Unlike models that rely on manual feature engineering, ANNs can automatically detect and combine patterns from raw inputs, allowing the model to “learn” what's important during training.
#
# **4. Flexibility and Scalability**
# ANN architectures can be expanded with more layers or neurons based on the complexity of the data, making them scalable for larger and more complex banking datasets in the future.
#
# **5. Robustness to Noise**
# Due to their layered structure and training optimization, ANNs can handle noisy or partially irrelevant data better than many traditional algorithms.
#
#
# ---
# ##Business Application##
# **The ANN-based churn prediction model enables banks to:**
#
#
#
#
#
# -Identify at-risk customers early and take preventive actions.
#
# -Boost customer retention through targeted offers and personalized services.
#
# -Reduce revenue loss by preventing the exit of high-value clients.
#
# -Optimize marketing efforts by focusing resources on likely churners.
#
# -Enhance customer experience using insights from churn behavior.
#
# -Support strategic planning with data-driven decision-making.
#
# ---
# ##Data Set Description##
# This project uses the Bank Customer Churn Dataset, which includes information about customers of a bank and whether they have churned (left the bank) or not. The dataset is designed for binary classification — to predict if a customer will churn (1) or stay (0).
#
# **Dataset Summary**
#
# **Total Records:** 10,000 customers (approx.)
#
# **Total Features:** 13 (12 input features + 1 target variable)
# ### 🗃️ Column Descriptions
#
# | Column Name        | Description                                                                 |
# |--------------------|-----------------------------------------------------------------------------|
# | `customer_id`       | Unique identifier for each customer                                         |
# | `credit_score`      | A numerical score representing the customer’s creditworthiness             |
# | `country`           | Country of residence (e.g., France, Spain, Germany)                        |
# | `gender`            | Gender of the customer                                                     |
# | `age`               | Age of the customer                                                        |
# | `tenure`            | Number of years the customer has stayed with the bank                      |
# | `balance`           | Account balance of the customer                                            |
# | `products_number`   | Number of bank products used by the customer                               |
# | `credit_card`       | Indicates if the customer owns a credit card (1 = Yes, 0 = No)             |
# | `active_member`     | Indicates if the customer is actively using the bank services (1 or 0)     |
# | `estimated_salary`  | Estimated annual salary of the customer                                    |
# | `churn`             | Target variable (1 = Churned, 0 = Retained)                                |
#
# ---
# ##Customer Churn Prediction in Banking Using Artificial Neural Network##
# **Analysis fron ANN Model**
#
# **The Artificial Neural Network (ANN) model achieved a training accuracy of ~85.1% and a validation accuracy of ~85.3%, with a relatively low validation loss of 0.3540**, indicating strong model performance and generalization. The model successfully learned the patterns and behaviors associated with customer churn in the banking sector.
#
# This demonstrates that ANN is effective for predicting churn using structured banking data, capturing complex nonlinear relationships between features like credit score, age, tenure, account balance, and customer activity.
#
# ##💼 Managerial Insights##
# **1.Customer Retention Focus**
#
# The bank can proactively identify high-risk churn customers and implement targeted retention strategies such as personalized offers, loyalty programs, or better engagement.
#
# **2.Critical Features Impacting Churn**
#
# Features such as age, credit score, account balance, and active membership were significant contributors to churn prediction. Banks can monitor and segment customers based on these variables to tailor services.
#
# **3.Early Warning System**
#
# With a robust model in place, the bank can develop an automated alert system to flag customers who are most likely to exit, allowing intervention before churn occurs.
#
# **4.Improved Customer Segmentation**
#
# Using prediction scores from the model, management can group customers into risk buckets (e.g., low, medium, high churn probability), optimizing resource allocation in marketing and service efforts.
#
# **5.Strategic Planning Support**
#
# The model adds value to strategic decisions like service customization, customer experience investments, and portfolio management by leveraging predictive insights.
#
# ---
# ##📊 Model Performance Summary & Strategic Business Implications##
# **✅ Conclusion:**
# **Model Performance Review**
#
# Over 50 training epochs, the Artificial Neural Network (ANN) demonstrates consistent and converging performance:
#
# 1.Training Accuracy increased from 74.2% at epoch 1 to 85.1% by epoch 50.
#
# 2.Validation Accuracy improved from 80.5% to 85.3%, closely tracking the training curve — a sign of strong generalization.
#
# 3.Training Loss dropped from 0.57 to 0.36, while Validation Loss reduced steadily from 0.47 to 0.35.
#
# 4.Importantly, no signs of overfitting or underfitting were observed — validation loss remained lower than training loss, indicating that the model is learning patterns rather than memorizing
#
# **💼 Managerial Insights: What This Means for the Bank**
#
# **📌 1. Early Detection of Customer Churn (~85.3% Accuracy)**
# The model can accurately identify 8.5 out of every 10 customers who are likely to churn.
#
# This predictive ability gives the bank a first-mover advantage to retain customers before they exit.
#
# **📌 2. Targeted Retention Campaigns**
# With precise churn predictions, the bank can:
#
# Offer tailored incentives to high-risk customers.
#
# Improve service levels in weak-performing regions.
#
# Reduce blanket marketing costs by focusing only on segments with high churn probability.
#
# **📌 3. Cost Efficiency and Resource Optimization**
# Reducing customer churn by even 5–10% using this model can result in substantial savings in customer acquisition costs and drive long-term profitability.
#
# Enables smarter allocation of call center resources, marketing spend, and loyalty rewards.
#
# **📌 4. Foundation for Explainability & Compliance**
# As the model performs reliably, the next logical step is to integrate explainability tools (like SHAP) to uncover:
#
# What factors drive churn (e.g., tenure, balance, activity).
#
# How internal policies can be tweaked to reduce risk factors.
#
# **📌 5. Scalable & Deployment-Ready Model**
# The model exhibits consistent behavior over all 50 epochs — it's ready to be:
#
# Deployed into the CRM system.
#
# Integrated into dashboards for real-time monitoring by customer service teams and managers.
#
# Periodically retrained to adapt to shifting customer behaviors.
#
# **🧠 Recommendation for Next Steps:**
# Use SHAP/LIME to extract feature importance insights.
#
# Build a real-time churn prediction dashboard for business users.
#
# Consider retraining the model quarterly to maintain high accuracy with evolving customer data.
#
# ---
#
# ##💡 Managerial Insights from Model Performance##
# The final evaluation of the model on unseen test data shows strong and consistent performance:
#
# ✅ Test Accuracy: 85.35%
#
# 📉 Test Loss: 0.3385
#
# 🏁 Validation Accuracy: Peaked around 85.8% during training
#
# 🔁 Train Accuracy: Consistently around 84.6% towards the final epochs
#
# **📌 Key Takeaways for Management:**
#
# **1.High Predictive Power:**
#
# An accuracy of 85.35% on test data confirms the model’s reliability in predicting customer churn behavior. This makes it a dependable asset for business decision-making.
#
# **2.Generalization Capability:**
#
# The close alignment between training, validation, and test accuracy (within ~1%) indicates minimal overfitting. The model generalizes well across different datasets, increasing confidence in real-world deployment.
#
# **3.Actionable Model:**
#
# The relatively low test loss (0.3385) reflects precise probability estimates. This allows the model to not only classify churners correctly but also provide risk scores—useful for prioritizing high-risk customers.
#
# **Strategic Use Cases:**
#
# **1.💼 Retention Campaigns:** Focus efforts on the top 15–20% of customers flagged with high churn probability.
#
# **2.📈 Resource Optimization:** Allocate retention resources more effectively, reducing cost per save.
#
# **3.🧠 Insight Generation:** Use churn drivers (from feature importance or SHAP analysis) to fine-tune product, pricing, or service policies.
#
# **4.Scalability & Monitoring:**
#
# With consistent performance across epochs and datasets, the model is scalable for use across branches or regions. A/B testing can be introduced post-deployment to validate impact in live environments.
#
# ---
#
# ##🔍 Understanding the F1 Score, Macro Avg, and Weighted Avg##
#
# **✅ F1 Score:**
#
# -F1 Score is the harmonic mean of precision and recall. It's especially useful in imbalanced datasets (like churn prediction).
#
# -It gives a single score to balance false positives and false negatives.
#
# **📊 Macro Average:**
#
# -This takes the simple average of the F1 scores of both classes (churn and non-churn), without considering class imbalance.
#
# -Macro F1 Score = 0.72 → Indicates moderate overall performance across both classes equally.
#
# **⚖️ Weighted Average:**
#
# -This considers the support (number of instances) for each class and calculates a weighted average of F1 scores.
#
# -Weighted F1 Score = 0.84 → Since class 0 (non-churners) dominates the data, the overall score is high due to better performance on the majority class.
#
# **📈 Managerial Implications**
#
# **1. Imbalanced Focus**
#
# -The model performs very well for non-churners (F1 = 0.91), but less accurately for churners (F1 = 0.53, recall = 0.41).
#
# -❗ This means 59% of churners are being missed, which is critical for a business aiming to reduce churn.
#
# → Action: Invest in techniques like SMOTE, cost-sensitive learning, or resampling to improve recall for churners.
#
# **2. Customer Retention Strategy Needs Fine-Tuning**
#
# -Since the model struggles with identifying a large portion of actual churners, relying on it as-is may leave many at-risk customers unattended.
#
# → Action: Use this model as a first-layer filter, but combine it with qualitative feedback or rule-based logic to catch more churners.
#
# **3. Business Cost Impact**
#
# -Missing churners (high false negatives) may lead to lost revenue, while misclassifying non-churners (false positives) leads to unnecessary retention costs.
#
# → Action: A cost-benefit analysis is recommended. If retaining a customer is more valuable than mistakenly targeting a few loyal ones, improving recall is more important.
#
# **4. Model Refinement Opportunity**
#
# -While the overall accuracy is strong (85%), the macro F1 (0.72) signals room for improvement in treating both classes equally.
#
# → Action: Incorporate techniques like ensemble models, class weights, or threshold tuning to improve minority class detection.
#
# ---
#
# ##🔍  ROC-AUC Score##
# ROC-AUC stands for **Receiver Operating Characteristic** - Area Under the Curve.
#
# ROC Curve: Plots the True Positive Rate (Recall) vs. False Positive Rate at various threshold levels.
#
# AUC Score (Area Under Curve): Measures the model’s ability to distinguish between the two classes.
#
# AUC = 1.0 → Perfect classifier
# AUC = 0.5 → Random guessing
# AUC = 0.8527 → Excellent model with ~85% probability that it ranks a random churner higher than a non-churner.
#
# **🏦 Implications in the Banking Sector (Customer Churn)**
#
# **✅ 1. Strong Discriminatory Power**
#
# -AUC of 0.8527 means the model is highly capable of distinguishing between customers likely to churn vs. those who won't.
#
# → Action: You can confidently use this model for churn prediction in your CRM or analytics platform.
#
# **💰 2. Improved Retention Campaign Targeting**
#
# -With this score, banks can identify churn-prone customers early and tailor retention offers (discounts, loyalty benefits).
#
# → Business Impact: Reduces customer attrition, improves lifetime value, and ensures higher ROI on retention marketing.
#
# **🎯 3. Risk Profiling**
# -The model can be embedded into core banking systems for real-time risk assessment of churn.
#
# → Helps segment customers into high-risk and low-risk churn groups for proactive engagement.
#
# ---
#
# ##🔍 Model Performance Insight (Post Hyperparameter Tuning)##
# After applying hyperparameter tuning using Keras Tuner, the Artificial Neural Network achieved the following results on the test dataset:
#
# ✅ Tuned Accuracy: 83.95%
#
# 📉 Tuned Loss: 0.3882
#
# 📈 Training Accuracy: 85.16%
#
# 🧪 Training Loss: 0.3523
#
# While the accuracy dropped slightly from the pre-tuned model (85.35% to 83.95%), the model is now less overfit, as evidenced by the smaller gap between training and test accuracy and the consistent loss values.
#
# **🧠 Managerial Insight for Banking Sector**
#
# **1.Model Stability & Generalization:**
#
# The tuned model demonstrates better generalization to unseen data. This ensures more consistent performance when deployed, reducing the risk of misclassification in real-world customer scenarios.
#
# **2.Customer Retention Strategies:**
#
# With an accuracy of ~84%, the bank can confidently identify patterns that indicate potential customer churn. Early intervention strategies like personalized offers, targeted communication, or service quality improvement can be rolled out to at-risk customers.
#
# **3.Cost Optimization:**
#
# Reducing false positives (wrongly predicting churn) minimizes the cost of unnecessary retention efforts, while catching true churners helps retain valuable customers. This model strikes a balance between these, optimizing resource allocation.
#
# **4.Data-Driven Decision-Making:**
#
# The ANN now serves as a robust decision support tool for the CRM and customer service teams. Management can confidently move forward with predictive churn analysis integrated into their dashboards and systems
#
# ---
#
# ##🔍 Model Comparison & Performance Analysis for Customer Churn Prediction##
# To evaluate the effectiveness of different machine learning models in predicting customer churn, we compared ANN, Logistic Regression, Random Forest, and XGBoost using standard classification metrics. The comparison includes Accuracy, ROC-AUC Score, Confusion Matrix, and Classification Report insights.
#
# | Model               | Accuracy | ROC-AUC Score | Precision (Churn) | Recall (Churn) | F1-Score (Churn) |
# |--------------------|----------|----------------|--------------------|----------------|------------------|
# | ✅ ANN              | 0.849    | 0.8395         | 0.71               | 0.43           | 0.53             |
# | 🔶 Logistic Regression | 0.808 | 0.7682         | 0.56               | 0.21           | 0.30             |
# | 🟢 Random Forest     | 0.852    | 0.8401         | 0.72               | 0.43           | 0.54             |
# | 🟣 XGBoost           | 0.843    | 0.8340         | 0.66               | 0.46           | 0.54             |
#
# ##💼 Managerial Implications##
# **Customer Retention Strategy:**
#
# Even top models like ANN and Random Forest misclassify nearly 57% of actual churners. Managers should use the predicted churn probabilities to flag high-risk customers for targeted retention campaigns.
#
# **Model Choice:**
#
# Random Forest and ANN offer the best balance between accuracy and churn identification. XGBoost is slightly better in recall but at the cost of more false positives.
#
# Logistic Regression is not recommended due to poor recall and lowest F1-score for churn class.
#
# **Class Imbalance Focus:**
#
# Given the lower recall across models for the churn class, the bank should consider resampling techniques (SMOTE, ADASYN) or cost-sensitive learning to enhance the sensitivity of the model to churn cases.
#
# **Probability-Driven Interventions:**
#
# Since ROC-AUC is high (~0.84), using churn probability thresholds rather than hard class labels can be more effective for tiered retention efforts.
#
# **Human-AI Collaboration:**
#
# Instead of blindly automating decisions, managers can use model outputs as decision-support tools, particularly for customers around the 0.4–0.6 churn probability zone.
#
# ##📌 Conclusion##
# The Artificial Neural Network (ANN) model built on the Bank Customer Churn dataset has shown robust performance in predicting customer churn with an overall accuracy of 85.35% on the test data. The model achieved a ROC-AUC score of 0.8527, indicating a strong ability to distinguish between churned and non-churned customers.
#
# Key performance metrics such as a macro F1-score of 0.72 and weighted F1-score of 0.84 further validate the model’s balance in handling class imbalance and delivering reliable predictions.
#
# From a managerial perspective, these results have strategic significance:
#
# The bank can confidently deploy this model to identify high-risk churn customers early and proactively intervene with personalized offers.
#
# The insights derived enable targeted retention strategies, optimizing customer relationship management (CRM) efforts.
#
# With continuous monitoring and minor enhancements, this model can be integrated into the core analytics infrastructure to reduce attrition rates, improve customer lifetime value, and enhance business profitability.

# %%
import zipfile
import os

# Unzip the file and list its contents
with zipfile.ZipFile("/content/bank_customer_churn_dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/")
    zip_ref.printdir()
# Out:
# File Name                                             Modified             Size
# Bank Customer Churn Prediction.csv             2022-08-30 15:01:36       561600

# %% [markdown]
# ##Load the Correct CSV File##

# %%
import pandas as pd

# Load the CSV with correct filename
df = pd.read_csv("/content/Bank Customer Churn Prediction.csv")
df.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %% [markdown]
# ##Understand and Explore the Data##

# %%
# Basic info
df.info()

# Check for missing values
df.isnull().sum()

# Describe the data
df.describe()

# See column names
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %% [markdown]
# ##Preprocess the Data##

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pandas as pd

# Copy the original dataframe
data = df.copy()

# Drop customer_id
data.drop('customer_id', axis=1, inplace=True)

# Label encode gender
le = LabelEncoder()
data['gender'] = le.fit_transform(data['gender'])

# One-hot encode 'country'
data = pd.get_dummies(data, columns=['country'], drop_first=True)

# Features and target
X = data.drop('churn', axis=1)
y = data['churn']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=59)

# %% [markdown]
# ##Build and Train the ANN Model##

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Build the ANN
model = Sequential()

# Input layer + First hidden layer
model.add(Dense(units=16, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.3))

# Second hidden layer
model.add(Dense(units=12, activation='relu'))
model.add(Dropout(0.3))

# Output layer
model.add(Dense(units=1, activation='sigmoid'))  # Binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5868 - loss: 0.6935 - val_accuracy: 0.7985 - val_loss: 0.4903
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7938 - loss: 0.5071 - val_accuracy: 0.7985 - val_loss: 0.4553
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7918 - loss: 0.4833 - val_accuracy: 0.7985 - val_loss: 0.4365
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7982 - loss: 0.4596 - val_accuracy: 0.8120 - val_loss: 0.4266
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8026 - loss: 0.4636 - val_accuracy: 0.8170 - val_loss: 0.4155
# ...

# %% [markdown]
# ##Visualize Accuracy and Loss##

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='green')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss', color='red')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation & Interpretation##

# %% [markdown]
# **Accuracy on test data**

# %%
# Evaluate accuracy on test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8610 - loss: 0.3378
# Test Accuracy: 0.8520

# %% [markdown]
# **Confusion Matrix & Classification Report**

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Predict classes (0 or 1)
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

# Classification Report
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion Matrix:
#  [[1560   37]
#  [ 259  144]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91      1597
#            1       0.80      0.36      0.49       403
#
#     accuracy                           0.85      2000
#    macro avg       0.83      0.67      0.70      2000
# weighted avg       0.85      0.85      0.83      2000

# %% [markdown]
# **ROC-AUC Score**

# %%
from sklearn.metrics import roc_auc_score

roc_score = roc_auc_score(y_test, y_pred_prob)
print(f"ROC-AUC Score: {roc_score:.4f}")
# Out:
# ROC-AUC Score: 0.8528

# %% [markdown]
# **HyperParameterTuning**

# %%
# !pip install keras-tuner --quiet

# %%
import keras_tuner as kt
from tensorflow.keras import layers

def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Dense(units=hp.Int('units_input', min_value=16, max_value=128, step=16), activation='relu', input_dim=X_train.shape[1]))
    model.add(layers.Dense(units=hp.Int('units_hidden', min_value=16, max_value=128, step=16), activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='churn_tuning',
    project_name='bank_churn_ann'
)

tuner.search(X_train, y_train, epochs=20, validation_split=0.2, verbose=1)
# Out:
# Reloading Tuner from churn_tuning/bank_churn_ann/tuner0.json

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
Best Hyperparameters:
- Input Layer Units: {best_hps.get('units_input')}
- Hidden Layer Units: {best_hps.get('units_hidden')}
- Learning Rate: {best_hps.get('learning_rate')}
""")
# Out:
# Best Hyperparameters:
# - Input Layer Units: 80
# - Hidden Layer Units: 64
# - Learning Rate: 0.001

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import keras_tuner as kt

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Dense(units=hp.Int('units_input', min_value=16, max_value=128, step=16),
                           activation='relu', input_dim=X_train.shape[1]))
    model.add(layers.Dense(units=hp.Int('units_hidden', min_value=16, max_value=128, step=16),
                           activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    executions_per_trial=2,
    directory='churn_tuning',
    project_name='bank_churn_ann'
)

tuner.search(X_train, y_train, epochs=20, validation_split=0.2, verbose=1)
# Out:
# Reloading Tuner from churn_tuning/bank_churn_ann/tuner0.json

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
🔧 Best Hyperparameters:
- Input Layer Units: {best_hps.get('units_input')}
- Hidden Layer Units: {best_hps.get('units_hidden')}
- Learning Rate: {best_hps.get('learning_rate')}
""")
# Out:
# 🔧 Best Hyperparameters:
# - Input Layer Units: 80
# - Hidden Layer Units: 64
# - Learning Rate: 0.001

# %%
# Build model with best hyperparameters
model = tuner.hypermodel.build(best_hps)

# Train with best setup
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8064 - loss: 0.4680 - val_accuracy: 0.8195 - val_loss: 0.4006
# Epoch 2/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8521 - loss: 0.3705 - val_accuracy: 0.8420 - val_loss: 0.3649
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8652 - loss: 0.3372 - val_accuracy: 0.8505 - val_loss: 0.3561
# Epoch 4/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8640 - loss: 0.3351 - val_accuracy: 0.8455 - val_loss: 0.3542
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8655 - loss: 0.3279 - val_accuracy: 0.8535 - val_loss: 0.3537
# ...

# %%
# Evaluate on test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"✅ Tuned Test Accuracy: {test_accuracy:.4f}")
print(f"📉 Tuned Test Loss: {test_loss:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8516 - loss: 0.3523
# ✅ Tuned Test Accuracy: 0.8395
# 📉 Tuned Test Loss: 0.3882

# %%
# !pip install scikeras

# %%
# Imports
import numpy as np
from sklearn.model_selection import StratifiedKFold, cross_val_score
from scikeras.wrappers import KerasClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define model function
def create_model():
    model = Sequential()
    model.add(Dense(64, input_dim=X.shape[1], activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # For binary classification
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Wrap in scikeras KerasClassifier
ann_model = KerasClassifier(model=create_model, epochs=30, batch_size=32, verbose=0)

# Build a pipeline with scaling + model
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', ann_model)
])

# Cross-validation config
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Perform cross-validation
cv_scores = cross_val_score(pipeline, X, y, cv=kfold, scoring='accuracy')

# Output results
print("Cross-Validation Accuracy Scores:", cv_scores)
print("Mean Accuracy: %.2f%% (+/- %.2f%%)" % (cv_scores.mean() * 100, cv_scores.std() * 100))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:978: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 140, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 380, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 90, in _cached_call
# ...

# %% [markdown]
#  ##Model Comparison##

# %%
# 📌 Step 1: Import Required Libraries
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score

# 📌 Step 2: Define Models
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
}

# 📌 Step 3: Train & Evaluate Traditional Models
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:,1]  # For ROC-AUC

    print(f"\n🔍 Model: {name}")
    print(f"✅ Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(f"📉 ROC-AUC Score: {roc_auc_score(y_test, y_proba):.4f}")
    print("📋 Classification Report:\n", classification_report(y_test, y_pred))
    print("📊 Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# 🔍 Model: Logistic Regression
# ✅ Accuracy: 0.8080
# 📉 ROC-AUC Score: 0.7682
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      1597
#            1       0.56      0.21      0.30       403
#
#     accuracy                           0.81      2000
#    macro avg       0.70      0.58      0.60      2000
# weighted avg       0.77      0.81      0.77      2000
#
# 📊 Confusion Matrix:
#  [[1532   65]
#  [ 319   84]]
#
# 🔍 Model: Random Forest
# ✅ Accuracy: 0.8560
# 📉 ROC-AUC Score: 0.8416
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      1597
#            1       0.74      0.43      0.55       403
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.70      0.73      2000
# weighted avg       0.85      0.86      0.84      2000
#
# 📊 Confusion Matrix:
#  [[1537   60]
#  [ 228  175]]
# ...

# %% [markdown]
# ##Compare with ANN##

# %%
from tensorflow import keras
from tensorflow.keras import layers

# ANN Model (already trained)
ann_model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
ann_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7572 - loss: 0.5268 - val_accuracy: 0.8194 - val_loss: 0.4166
# Epoch 2/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8340 - loss: 0.3923 - val_accuracy: 0.8431 - val_loss: 0.3833
# Epoch 3/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8522 - loss: 0.3619 - val_accuracy: 0.8450 - val_loss: 0.3672
# Epoch 4/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8625 - loss: 0.3380 - val_accuracy: 0.8462 - val_loss: 0.3616
# Epoch 5/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8666 - loss: 0.3303 - val_accuracy: 0.8494 - val_loss: 0.3522
# ...

# %% [markdown]
# ##Now Compare ANN with Other Models (Logistic, RF, XGBoost)##

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# 1. ANN
ann_loss, ann_accuracy = ann_model.evaluate(X_test, y_test, verbose=0)
y_pred_ann = ann_model.predict(X_test)
y_pred_ann_class = (y_pred_ann > 0.5).astype(int)

print("🔷 ANN Model")
print("Accuracy:", ann_accuracy)
print("ROC AUC Score:", roc_auc_score(y_test, y_pred_ann))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_ann_class))
print("Classification Report:\n", classification_report(y_test, y_pred_ann_class))


# 2. Logistic Regression
log_model = LogisticRegression()
log_model.fit(X_train, y_train)
y_pred_log = log_model.predict(X_test)
y_proba_log = log_model.predict_proba(X_test)[:, 1]

print("\n🔶 Logistic Regression")
print("Accuracy:", log_model.score(X_test, y_test))
print("ROC AUC Score:", roc_auc_score(y_test, y_proba_log))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_log))
print("Classification Report:\n", classification_report(y_test, y_pred_log))


# 3. Random Forest
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
y_proba_rf = rf_model.predict_proba(X_test)[:, 1]

print("\n🟢 Random Forest")
print("Accuracy:", rf_model.score(X_test, y_test))
print("ROC AUC Score:", roc_auc_score(y_test, y_proba_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))


# 4. XGBoost
xgb_model = XGBClassifier(eval_metric='logloss', use_label_encoder=False)
xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)
y_proba_xgb = xgb_model.predict_proba(X_test)[:, 1]

print("\n🟣 XGBoost")
print("Accuracy:", xgb_model.score(X_test, y_test))
print("ROC AUC Score:", roc_auc_score(y_test, y_proba_xgb))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
print("Classification Report:\n", classification_report(y_test, y_pred_xgb))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 🔷 ANN Model
# Accuracy: 0.8489999771118164
# ROC AUC Score: 0.8395269666605034
# Confusion Matrix:
#  [[1525   72]
#  [ 230  173]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      1597
#            1       0.71      0.43      0.53       403
#
#     accuracy                           0.85      2000
#    macro avg       0.79      0.69      0.72      2000
# weighted avg       0.84      0.85      0.83      2000
#
#
# 🔶 Logistic Regression
# Accuracy: 0.808
# ROC AUC Score: 0.7682223648248654
# Confusion Matrix:
#  [[1532   65]
#  [ 319   84]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      1597
#            1       0.56      0.21      0.30       403
#
#     accuracy                           0.81      2000
#    macro avg       0.70      0.58      0.60      2000
# ...

# %% [markdown]
# --------------------------------------------End of Project-------------------------------------------------------------------------
